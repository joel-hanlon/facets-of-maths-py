# %% [markdown]
# # Intro
# hey guys!!!!!!

# %% [markdown]
# This takes Matt Parker's values for the perimeter of an ellipse relative to the ratio between `a` and `b`.

# %%
import numpy as np
import math

ellipseLengths = np.loadtxt('group-poster/ellipse-lengths.csv', 
                            skiprows = 1, 
                            delimiter = ',')
